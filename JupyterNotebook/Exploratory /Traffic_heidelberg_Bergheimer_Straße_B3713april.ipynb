# %% [markdown]
# ### notes and samples

# %% [raw]
# #one hot encoding using OneHotEncoder of Scikit-Learn
#
# import pandas as pd
# from sklearn.preprocessing import OneHotEncoder
#
# #Building a dummy employee dataset for example
# data = {'Employee id': [10, 20, 15, 25, 30],
#         'Gender': ['M', 'F', 'F', 'M', 'F'],
#         'Remarks': ['Good', 'Nice', 'Good', 'Great', 'Nice'],
#         }
# #Converting into a Pandas dataframe
# df = pd.DataFrame(data)
# #Print the dataframe:
# print(f"Employee data : \n{df}")
#
# #Extract categorical columns from the dataframe
# #Here we extract the columns with object datatype as they are the categorical columns
# categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
#
# #Initialize OneHotEncoder
# encoder = OneHotEncoder(sparse_output=False)
#
# # Apply one-hot encoding to the categorical columns
# one_hot_encoded = encoder.fit_transform(df[categorical_columns])
#
# #Create a DataFrame with the one-hot encoded columns
# #We use get_feature_names_out() to get the column names for the encoded data
# one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(categorical_columns))
#
# # Concatenate the one-hot encoded dataframe with the original dataframe
# df_encoded = pd.concat([df, one_hot_df], axis=1)
#
# # Drop the original categorical columns
# df_encoded = df_encoded.drop(categorical_columns, axis=1)
#
# # Display the resulting dataframe
# print(f"Encoded Employee data : \n{df_encoded}")

# %% [raw]
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np
#
# # Extract hour of the day from recvTime
# data['hourOfDay'] = data['recvTime'].dt.hour
#
# # One-hot encode 'vehicleType'
# encoder = OneHotEncoder(sparse=False)
# vehicle_type_encoded = encoder.fit_transform(data[['vehicleType']])
#
# # Create a DataFrame for the encoded vehicleType features
# vehicle_type_encoded_df = pd.DataFrame(vehicle_type_encoded, columns=encoder.get_feature_names_out(['vehicleType']))
#
# # Concatenate the encoded vehicleType features back with the original DataFrame
# data_preprocessed = pd.concat([data, vehicle_type_encoded_df], axis=1)
#
# # Prepare the data for machine learning model
# # Define features and target variable
# features = pd.concat([data_preprocessed[['hourOfDay', 'latitude', 'longitude']], vehicle_type_encoded_df], axis=1)
# target = data_preprocessed['intensity']
#
# features.head(), target.head()

# %% [raw]
# he 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this erro

# %% [raw]
# Interactive plot wiht plotly in notebook
# https://plotly.com/python/line-charts/
#
# Time Series Forecasting With Prophet in Python
# https://machinelearningmastery.com/time-series-forecasting-with-prophet-in-python/
#
# ARIMA and SARIMAX models with Python
# https://cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#
# Tbleau traffic visu:
# https://public.tableau.com/app/profile/docinsight/viz/COVIDtrafficinIrelandrepoint/MobilityDashboard
#
# LSTM model ( but dont use it)
# https://www.sciencedirect.com/science/article/pii/S1877050922009917

# %% [raw]
#  valid values in Pandas 'Freq' tags
# https://stackoverflow.com/questions/35339139/what-values-are-valid-in-pandas-freq-tags
#
# Alias    Description
# B        business day frequency
# C        custom business day frequency
# D        calendar day frequency
# W        weekly frequency
# M        month end frequency
# SM       semi-month end frequency (15th and end of month)
# BM       business month end frequency
# CBM      custom business month end frequency
# MS       month start frequency
# SMS      semi-month start frequency (1st and 15th)
# BMS      business month start frequency
# CBMS     custom business month start frequency
# Q        quarter end frequency
# BQ       business quarter end frequency
# QS       quarter start frequency
# BQS      business quarter start frequency
# A, Y     year end frequency
# BA, BY   business year end frequency
# AS, YS   year start frequency
# BAS, BYS business year start frequency
# BH       business hour frequency
# H        hourly frequency
# T, min   minutely frequency
# S        secondly frequency
# L, ms    milliseconds
# U, us    microseconds
# N        nanoseconds
#
# Weekly frequencies can have anchors on any day of the week: W-SUN, W-MON, W-TUE, W-WED, W-THU, W-FRI and W-SAT.
# For example, to anchor weeks to end on Mondays, you can use W-MON (note that it is case-insensitive).
# anchir offsets :
# https://pandas.pydata.org/docs/user_guide/timeseries.html#anchored-offsets

# %% [raw]
# pyspark.pandas.Series.dt.normalize
# dt.normalize() → pyspark.pandas.series.Series
# Convert times to midnight.
#
# The time component of the date-time is converted to midnight i.e. 00:00:00. This is useful in cases, when the time does not matter. Length is unaltered. The time zones are unaffected.

# %%
pd.offsets.__all__
# Out:
# ['Day',
#  'BaseOffset',
#  'BusinessDay',
#  'BusinessMonthBegin',
#  'BusinessMonthEnd',
#  'BDay',
#  'CustomBusinessDay',
#  'CustomBusinessMonthBegin',
#  'CustomBusinessMonthEnd',
#  'CDay',
#  'CBMonthEnd',
#  'CBMonthBegin',
#  'MonthBegin',
#  'BMonthBegin',
#  'MonthEnd',
#  'BMonthEnd',
#  'SemiMonthEnd',
#  'SemiMonthBegin',
#  'BusinessHour',
#  'CustomBusinessHour',
#  'YearBegin',
#  'BYearBegin',
#  'YearEnd',
#  'BYearEnd',
#  'QuarterBegin',
#  'BQuarterBegin',
#  'QuarterEnd',
#  'BQuarterEnd',
#  'LastWeekOfMonth',
#  'FY5253Quarter',
#  'FY5253',
#  'Week',
#  'WeekOfMonth',
#  'Easter',
#  'Tick',
#  'Hour',
#  'Minute',
#  'Second',
#  'Milli',
#  'Micro',
#  'Nano',
#  'DateOffset']

# %%
pd.offsets.MonthBegin._prefix # 'MS'
pd.offsets.WeekOfMonth._prefix
# Out:
# 'WOM'

# %% [markdown]
# ## Dataset
# Traffic cameras in the city of Heidelberg
# The dataset contains an observation of the traffic flow at a specific place and time. It contains current and past measurements from traffic cameras in the city of Heidelberg (measurement interval: 15 min).
# In addition to general location information, each dataset contains, if available, information on the number of vehicles and vehicle types measured, the average distance between vehicles and their passing time.
# A detailed description of the dataset,the specification, and the raw data can be found here:
# https://ckan.datenplattform.heidelberg.de/de/dataset/mobility_main_trafficcamera

# %% [markdown]
# ### Research Questions and machine learning objective
# How does traffic intensity vary throughout the day?
#
# We will analyze the intensity of traffic at different times of the day to identify peak traffic hours. This involves aggregating traffic data by hour and visualizing the average traffic intensity.
#
# Does traffic intensity vary by vehicleType?
# We aim to explore whether certain types of vehicles are more prevalent during specific times or in certain locations, contributing differently to overall traffic intensity.
#
#
# Machine Learning Model:
# Objective: Predict the traffic intensity based on time of day, location (latitude and longitude), and vehicleType.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# pmdarima
from pmdarima import ARIMA
from pmdarima import auto_arima

# statsmodels
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# skforecast
from skforecast.Sarimax import Sarimax
from skforecast.ForecasterSarimax import ForecasterSarimax
from skforecast.model_selection_sarimax import backtesting_sarimax
from skforecast.model_selection_sarimax import grid_search_sarimax
from sklearn.metrics import mean_absolute_error

import warnings

# %%
Bergheimer_Straße_B37 ='b95871b2-7de0-46b1-b377-db497250f8a0.csv'
data = pd.read_csv(Bergheimer_Straße_B37)

# %% [markdown]
# ### Initial analysis and data wrangling

# %% [raw]
# Neckarstaden_1_3 = '2a469ef6-634b-435a-874b-9fd40ba9bd5c.csv'
# Am_Hackteufel_2 ='2d93d846-83c2-4b2c-afbd-25c17d421c0d.csv'
# Im_Neuenheimer_Feld_253 ='4d63ef2f-d4c2-4cf1-81a8-ec9430d74725.csv'
# Vangerowstraße_69 ='4fdf4ee7-c226-4a33-a695-85f6c9e712f1.csv'
# Kirchheimer_Weg_14 ='05e8ef1c-fcf6-473c-89cc-bfab0accdcf1.csv'
# Mönchhofstraße_6 = '7e6b52dd-740b-4e1f-9c74-467905bc10ba.csv'
# Lessingstrasse_15 = '5725a391-c537-4724-9575-abc0fd7bc47a.csv'
# Vangerowstraße_103 = 'b266a9b9-7a63-46b0-b8ce-408fd7395512.csv'
# Lessingstraße_12 = 'dc5200b1-8783-4800-82cb-4f5718c00581.csv'
# Baumschulenweg_12 = 'ef443489-03bf-4607-9bc7-41472473639c.csv'
# L637 = '6c3c621c-8710-4485-ac45-e201879cf9ae.csv'
#
# data2 = pd.read_csv(Neckarstaden_1_3)
# data3 = pd.read_csv(Am_Hackteufel_2)
# data4 = pd.read_csv(Im_Neuenheimer_Feld_253)
# data5 = pd.read_csv(Vangerowstraße_69)
# data6 = pd.read_csv(Kirchheimer_Weg_14)
# data7 = pd.read_csv(Mönchhofstraße_6)
# data8 = pd.read_csv(Lessingstrasse_15)
# data9 = pd.read_csv(Vangerowstraße_103)
# data10 = pd.read_csv(Bergheimer_Straße_B37)
# data11 = pd.read_csv(Lessingstraße_12)
# data12 = pd.read_csv(Baumschulenweg_12)
# datasets = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12]
#
# datasets = {
#     'data1': data1,
#     'data2': data2,
#     'data3': data3,
#     'data4': data4,
#     'data5': data5,
#     'data6': data6,
#     'data7': data7,
#     'data8': data8,
#     'data9': data9,
#     'data10': data10,
#     'data11': data11,
#     'data12': data12,
# }

# %% [raw]
# for name, dataset in datasets.items():
#     print(f'\n {name}')
#     print (dataset.info())

# %% [raw]
# for name, dataset in datasets.items():
#     null =[col for col in dataset.columns if dataset[col].isna().sum() == dataset.shape[0]]
#     print(f'\n {name},{null}')

# %% [raw]
# data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12], axis=0)
#
# print(data.shape)
# data.head()

# %% [markdown]
# #### Merging all datasets

# %%
null =[col for col in data.columns if data[col].isna().sum() == data.shape[0]]
data = data.drop(columns = null)

# %%
col_to_check = ['fiwareServicePath','entityId','entityType','addressLocality','addressCountry']
for col in col_to_check:
    print(data[col].unique())
# Out:
# ['/main/trafficcamera']
# ['urn:ngsiv2:TrafficFlowObserved:2d458741-2a9a-45ba-a062-f8a790a976aa']
# ['TrafficFlowObserved']
# ['Heidelberg']
# ['Deutschland']

# %%
data = data.drop(columns = col_to_check)

# %%
data
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#            _id                  recvTime   latitude  postalCode vehicleType  \
# 0            1  2022-11-03T14:05:24.567Z  49.408167       69115         car
# 1            2  2022-11-03T14:05:24.617Z  49.408167       69115  motorcycle
# 2            3  2022-11-03T14:05:24.666Z  49.408167       69115         van
# 3            4  2022-11-03T14:05:24.666Z  49.408167       69115       lorry
# 4            5  2022-11-03T14:15:20.829Z  49.408167       69115         car
# ...        ...                       ...        ...         ...         ...
# 116466  116883  2024-02-01T09:00:21.544Z  49.408167       69115       lorry
# 116467  116884  2024-02-01T09:15:21.380Z  49.408167       69115         car
# 116468  116885  2024-02-01T09:15:21.666Z  49.408167       69115  motorcycle
# 116469  116886  2024-02-01T09:15:21.872Z  49.408167       69115         van
# 116470  116887   2024-02-01T09:15:22.88Z  49.408167       69115       lorry
#
#         longitude            dateObservedTo              dateObserved  \
# 0         8.66825  2022-11-03T13:55:00.000Z  2022-11-03T13:55:00.000Z
# 1         8.66825  2022-11-03T13:55:00.000Z  2022-11-03T13:55:00.000Z
# 2         8.66825  2022-11-03T13:55:00.000Z  2022-11-03T13:55:00.000Z
# 3         8.66825  2022-11-03T13:55:00.000Z  2022-11-03T13:55:00.000Z
# 4         8.66825  2022-11-03T14:10:00.000Z  2022-11-03T14:10:00.000Z
# ...           ...                       ...                       ...
# 116466    8.66825  2024-02-01T08:55:00.000Z  2024-02-01T08:55:00.000Z
# 116467    8.66825  2024-02-01T09:10:00.000Z  2024-02-01T09:10:00.000Z
# 116468    8.66825  2024-02-01T09:10:00.000Z  2024-02-01T09:10:00.000Z
# 116469    8.66825  2024-02-01T09:10:00.000Z  2024-02-01T09:10:00.000Z
# 116470    8.66825  2024-02-01T09:10:00.000Z  2024-02-01T09:10:00.000Z
#
#                 dateObservedFrom  intensity          streetAddress
# 0       2022-11-03T13:40:00.000Z        243  Bergheimer Straße B37
# 1       2022-11-03T13:40:00.000Z          5  Bergheimer Straße B37
# 2       2022-11-03T13:40:00.000Z         44  Bergheimer Straße B37
# 3       2022-11-03T13:40:00.000Z         46  Bergheimer Straße B37
# 4       2022-11-03T13:55:00.000Z        273  Bergheimer Straße B37
# ...                          ...        ...                    ...
# 116466  2024-02-01T08:40:00.000Z         10  Bergheimer Straße B37
# 116467  2024-02-01T08:55:00.000Z         22  Bergheimer Straße B37
# 116468  2024-02-01T08:55:00.000Z          2  Bergheimer Straße B37
# 116469  2024-02-01T08:55:00.000Z          4  Bergheimer Straße B37
# 116470  2024-02-01T08:55:00.000Z          3  Bergheimer Straße B37
#
# [116471 rows x 11 columns]

# %%
data = data.drop_duplicates()
data = data.reset_index(drop =True)

# %% [markdown]
# #### Converting formats

# %% [raw]
# # notes :
# Use pd.to_datetime: Convert strings or other date formats into datetime64[ns].
# Use .dt: Extract datetime components directly from a datetime Series.
# Use pd.DatetimeIndex: Generally used for when you need a datetime index for datetime operations, like time-series data manipulation or when the index itself needs datetime properties. For simple extraction of date components, stick with .dt.

# %%
# Converting the types
data['recvTime'] = pd.to_datetime(data['recvTime'])
data['dateObserved'] = pd.to_datetime(data['dateObserved'])
data['dateObservedFrom'] = pd.to_datetime(data['dateObservedFrom'])
data['dateObservedTo'] = pd.to_datetime(data['dateObservedTo'])

# %%
data['hourOfDay'] = data['dateObserved'].dt.hour
data['date'] = data['dateObserved'].dt.date
data['year'] = pd.DatetimeIndex(data['date']).year
data['month'] = pd.DatetimeIndex(data['date']).month
data['days_of_week'] = pd.DatetimeIndex(data['date']).day_name()
data['date'] =pd.to_datetime(data['date'])

# %% [raw]
# data.to_csv('merged_data.csv')

# %% [raw]
# # note
# # library for casting of time serries takes into account the holidays, the ml method is called prophet, "sktime" for making prediction of time serries
# # df.asfreq(15 minutes) ->  search it ! for the frequency of date columns

# %% [markdown]
# ####  Checking for gaps in time series

# %% [raw]
# # note when  the necessary time-indexed operations done and want to revert dateObserved from an index back to a column, use .reset_index():
# gap_reset = gap.reset_index()

# %%
data.dtypes
# Out:
# _id                               int64
# recvTime            datetime64[ns, UTC]
# latitude                        float64
# postalCode                        int64
# vehicleType                      object
# longitude                       float64
# dateObservedTo      datetime64[ns, UTC]
# dateObserved        datetime64[ns, UTC]
# dateObservedFrom    datetime64[ns, UTC]
# intensity                         int64
# streetAddress                    object
# hourOfDay                         int32
# date                     datetime64[ns]
# year                              int32
# month                             int32
# days_of_week                     object
# dtype: object

# %%
data[data['date']== '2022-11-09'].head(50)
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#        _id                         recvTime   latitude  postalCode  \
# 1730  1731 2022-11-09 07:00:19.789000+00:00  49.408167       69115
# 1731  1732 2022-11-09 07:00:19.871000+00:00  49.408167       69115
# 1732  1733 2022-11-09 07:00:19.971000+00:00  49.408167       69115
# 1733  1734 2022-11-09 07:00:19.982000+00:00  49.408167       69115
# 1864  1865 2022-11-09 07:30:31.954000+00:00  49.408167       69115
# 1865  1866 2022-11-09 07:30:32.940000+00:00  49.408167       69115
# 1866  1867 2022-11-09 07:30:32.188000+00:00  49.408167       69115
# 1867  1868 2022-11-09 07:30:32.239000+00:00  49.408167       69115
# 1886  1887 2022-11-09 07:32:04.467000+00:00  49.408167       69115
# 1887  1888 2022-11-09 07:32:04.481000+00:00  49.408167       69115
# 1888  1889 2022-11-09 07:32:04.570000+00:00  49.408167       69115
# 1889  1890 2022-11-09 07:32:17.426000+00:00  49.408167       69115
# 1890  1891 2022-11-09 07:32:17.487000+00:00  49.408167       69115
# 1891  1892 2022-11-09 07:32:30.279000+00:00  49.408167       69115
# 1892  1893 2022-11-09 07:32:30.282000+00:00  49.408167       69115
# 1893  1894 2022-11-09 07:32:41.356000+00:00  49.408167       69115
# 1894  1895 2022-11-09 07:32:41.393000+00:00  49.408167       69115
# 1895  1896 2022-11-09 07:32:41.395000+00:00  49.408167       69115
# 1896  1897 2022-11-09 07:32:54.161000+00:00  49.408167       69115
# 1897  1898 2022-11-09 07:32:54.195000+00:00  49.408167       69115
# 1898  1899 2022-11-09 07:33:07.119000+00:00  49.408167       69115
# 1899  1900 2022-11-09 07:33:07.121000+00:00  49.408167       69115
# 1900  1901 2022-11-09 07:33:29.417000+00:00  49.408167       69115
# 1901  1902 2022-11-09 07:33:29.469000+00:00  49.408167       69115
# 1902  1903 2022-11-09 07:33:29.474000+00:00  49.408167       69115
# 1903  1904 2022-11-09 07:33:29.483000+00:00  49.408167       69115
# 1904  1905 2022-11-09 07:33:42.659000+00:00  49.408167       69115
# 1905  1906 2022-11-09 07:33:42.661000+00:00  49.408167       69115
# 1906  1907 2022-11-09 07:33:42.682000+00:00  49.408167       69115
# 1907  1908 2022-11-09 07:33:49.830000+00:00  49.408167       69115
# 1908  1909 2022-11-09 07:33:49.169000+00:00  49.408167       69115
# 1909  1910 2022-11-09 07:33:49.173000+00:00  49.408167       69115
# 1910  1911 2022-11-09 07:34:03.840000+00:00  49.408167       69115
# 1911  1912 2022-11-09 07:34:03.880000+00:00  49.408167       69115
# 1912  1913 2022-11-09 07:34:03.175000+00:00  49.408167       69115
# 1913  1914 2022-11-09 07:34:03.269000+00:00  49.408167       69115
# 1914  1915 2022-11-09 07:34:15.208000+00:00  49.408167       69115
# 1915  1916 2022-11-09 07:34:15.269000+00:00  49.408167       69115
# 1916  1917 2022-11-09 07:34:28.430000+00:00  49.408167       69115
# 1917  1918 2022-11-09 07:34:28.500000+00:00  49.408167       69115
# 1918  1919 2022-11-09 07:34:40.136000+00:00  49.408167       69115
# 1919  1920 2022-11-09 07:34:40.174000+00:00  49.408167       69115
# 1920  1921 2022-11-09 07:34:40.272000+00:00  49.408167       69115
# 1921  1922 2022-11-09 07:34:53.314000+00:00  49.408167       69115
# 1922  1923 2022-11-09 07:34:53.369000+00:00  49.408167       69115
# 1923  1924 2022-11-09 07:34:53.373000+00:00  49.408167       69115
# 1924  1925 2022-11-09 07:35:05.504000+00:00  49.408167       69115
# 1925  1926 2022-11-09 07:35:05.569000+00:00  49.408167       69115
# 1926  1927 2022-11-09 07:35:05.583000+00:00  49.408167       69115
# 1927  1928 2022-11-09 07:35:05.671000+00:00  49.408167       69115
#
#      vehicleType  longitude            dateObservedTo  \
# 1730         car    8.66825 2022-11-09 06:55:00+00:00
# 1731  motorcycle    8.66825 2022-11-09 06:55:00+00:00
# 1732         van    8.66825 2022-11-09 06:55:00+00:00
# 1733       lorry    8.66825 2022-11-09 06:55:00+00:00
# 1864         car    8.66825 2022-11-09 07:25:00+00:00
# 1865  motorcycle    8.66825 2022-11-09 07:25:00+00:00
# 1866         van    8.66825 2022-11-09 07:25:00+00:00
# 1867       lorry    8.66825 2022-11-09 07:25:00+00:00
# 1886         car    8.66825 2022-11-09 00:10:00+00:00
# 1887  motorcycle    8.66825 2022-11-09 00:10:00+00:00
# 1888       lorry    8.66825 2022-11-09 00:10:00+00:00
# 1889         car    8.66825 2022-11-09 00:25:00+00:00
# 1890       lorry    8.66825 2022-11-09 00:25:00+00:00
# 1891  motorcycle    8.66825 2022-11-09 00:40:00+00:00
# 1892       lorry    8.66825 2022-11-09 00:40:00+00:00
# 1893         car    8.66825 2022-11-09 00:55:00+00:00
# 1894       lorry    8.66825 2022-11-09 00:55:00+00:00
# 1895  motorcycle    8.66825 2022-11-09 00:55:00+00:00
# 1896         car    8.66825 2022-11-09 01:10:00+00:00
# 1897       lorry    8.66825 2022-11-09 01:10:00+00:00
# 1898         car    8.66825 2022-11-09 01:25:00+00:00
# 1899       lorry    8.66825 2022-11-09 01:25:00+00:00
# 1900         car    8.66825 2022-11-09 01:55:00+00:00
# 1901  motorcycle    8.66825 2022-11-09 01:55:00+00:00
# 1902         van    8.66825 2022-11-09 01:55:00+00:00
# 1903       lorry    8.66825 2022-11-09 01:55:00+00:00
# 1904         car    8.66825 2022-11-09 02:10:00+00:00
# 1905         van    8.66825 2022-11-09 02:10:00+00:00
# 1906       lorry    8.66825 2022-11-09 02:10:00+00:00
# 1907         van    8.66825 2022-11-09 02:25:00+00:00
# 1908         car    8.66825 2022-11-09 02:25:00+00:00
# 1909       lorry    8.66825 2022-11-09 02:25:00+00:00
# 1910         car    8.66825 2022-11-09 02:40:00+00:00
# 1911  motorcycle    8.66825 2022-11-09 02:40:00+00:00
# 1912         van    8.66825 2022-11-09 02:40:00+00:00
# 1913       lorry    8.66825 2022-11-09 02:40:00+00:00
# 1914         car    8.66825 2022-11-09 02:55:00+00:00
# 1915       lorry    8.66825 2022-11-09 02:55:00+00:00
# 1916  motorcycle    8.66825 2022-11-09 03:10:00+00:00
# 1917       lorry    8.66825 2022-11-09 03:10:00+00:00
# 1918  motorcycle    8.66825 2022-11-09 03:25:00+00:00
# 1919         car    8.66825 2022-11-09 03:25:00+00:00
# 1920       lorry    8.66825 2022-11-09 03:25:00+00:00
# 1921         car    8.66825 2022-11-09 03:40:00+00:00
# 1922         van    8.66825 2022-11-09 03:40:00+00:00
# 1923       lorry    8.66825 2022-11-09 03:40:00+00:00
# 1924         car    8.66825 2022-11-09 03:55:00+00:00
# 1925  motorcycle    8.66825 2022-11-09 03:55:00+00:00
# 1926       lorry    8.66825 2022-11-09 03:55:00+00:00
# 1927         van    8.66825 2022-11-09 03:55:00+00:00
#
#                   dateObserved          dateObservedFrom  intensity  \
# 1730 2022-11-09 06:55:00+00:00 2022-11-09 06:40:00+00:00        184
# 1731 2022-11-09 06:55:00+00:00 2022-11-09 06:40:00+00:00         22
# 1732 2022-11-09 06:55:00+00:00 2022-11-09 06:40:00+00:00         12
# 1733 2022-11-09 06:55:00+00:00 2022-11-09 06:40:00+00:00         21
# 1864 2022-11-09 07:25:00+00:00 2022-11-09 07:10:00+00:00        230
# 1865 2022-11-09 07:25:00+00:00 2022-11-09 07:10:00+00:00         21
# 1866 2022-11-09 07:25:00+00:00 2022-11-09 07:10:00+00:00          5
# 1867 2022-11-09 07:25:00+00:00 2022-11-09 07:10:00+00:00         24
# 1886 2022-11-09 00:10:00+00:00 2022-11-08 23:55:00+00:00          1
# 1887 2022-11-09 00:10:00+00:00 2022-11-08 23:55:00+00:00          1
# 1888 2022-11-09 00:10:00+00:00 2022-11-08 23:55:00+00:00          1
# 1889 2022-11-09 00:25:00+00:00 2022-11-09 00:10:00+00:00          2
# 1890 2022-11-09 00:25:00+00:00 2022-11-09 00:10:00+00:00          1
# 1891 2022-11-09 00:40:00+00:00 2022-11-09 00:25:00+00:00          1
# 1892 2022-11-09 00:40:00+00:00 2022-11-09 00:25:00+00:00          1
# 1893 2022-11-09 00:55:00+00:00 2022-11-09 00:40:00+00:00          2
# 1894 2022-11-09 00:55:00+00:00 2022-11-09 00:40:00+00:00          2
# 1895 2022-11-09 00:55:00+00:00 2022-11-09 00:40:00+00:00          1
# 1896 2022-11-09 01:10:00+00:00 2022-11-09 00:55:00+00:00          2
# 1897 2022-11-09 01:10:00+00:00 2022-11-09 00:55:00+00:00          0
# 1898 2022-11-09 01:25:00+00:00 2022-11-09 01:10:00+00:00          7
# 1899 2022-11-09 01:25:00+00:00 2022-11-09 01:10:00+00:00          1
# 1900 2022-11-09 01:55:00+00:00 2022-11-09 01:40:00+00:00          2
# 1901 2022-11-09 01:55:00+00:00 2022-11-09 01:40:00+00:00          1
# 1902 2022-11-09 01:55:00+00:00 2022-11-09 01:40:00+00:00          2
# 1903 2022-11-09 01:55:00+00:00 2022-11-09 01:40:00+00:00          1
# 1904 2022-11-09 02:10:00+00:00 2022-11-09 01:55:00+00:00          1
# 1905 2022-11-09 02:10:00+00:00 2022-11-09 01:55:00+00:00          1
# 1906 2022-11-09 02:10:00+00:00 2022-11-09 01:55:00+00:00          0
# 1907 2022-11-09 02:25:00+00:00 2022-11-09 02:10:00+00:00          2
# 1908 2022-11-09 02:25:00+00:00 2022-11-09 02:10:00+00:00          2
# 1909 2022-11-09 02:25:00+00:00 2022-11-09 02:10:00+00:00          2
# 1910 2022-11-09 02:40:00+00:00 2022-11-09 02:25:00+00:00          6
# 1911 2022-11-09 02:40:00+00:00 2022-11-09 02:25:00+00:00          1
# 1912 2022-11-09 02:40:00+00:00 2022-11-09 02:25:00+00:00          1
# 1913 2022-11-09 02:40:00+00:00 2022-11-09 02:25:00+00:00          2
# 1914 2022-11-09 02:55:00+00:00 2022-11-09 02:40:00+00:00          1
# 1915 2022-11-09 02:55:00+00:00 2022-11-09 02:40:00+00:00          0
# 1916 2022-11-09 03:10:00+00:00 2022-11-09 02:55:00+00:00          2
# 1917 2022-11-09 03:10:00+00:00 2022-11-09 02:55:00+00:00          1
# 1918 2022-11-09 03:25:00+00:00 2022-11-09 03:10:00+00:00          2
# 1919 2022-11-09 03:25:00+00:00 2022-11-09 03:10:00+00:00          5
# 1920 2022-11-09 03:25:00+00:00 2022-11-09 03:10:00+00:00          1
# 1921 2022-11-09 03:40:00+00:00 2022-11-09 03:25:00+00:00          6
# 1922 2022-11-09 03:40:00+00:00 2022-11-09 03:25:00+00:00          1
# 1923 2022-11-09 03:40:00+00:00 2022-11-09 03:25:00+00:00          1
# 1924 2022-11-09 03:55:00+00:00 2022-11-09 03:40:00+00:00         13
# 1925 2022-11-09 03:55:00+00:00 2022-11-09 03:40:00+00:00          2
# 1926 2022-11-09 03:55:00+00:00 2022-11-09 03:40:00+00:00          1
# 1927 2022-11-09 03:55:00+00:00 2022-11-09 03:40:00+00:00          2
#
#               streetAddress  hourOfDay       date  year  month days_of_week
# 1730  Bergheimer Straße B37          6 2022-11-09  2022     11    Wednesday
# 1731  Bergheimer Straße B37          6 2022-11-09  2022     11    Wednesday
# 1732  Bergheimer Straße B37          6 2022-11-09  2022     11    Wednesday
# 1733  Bergheimer Straße B37          6 2022-11-09  2022     11    Wednesday
# 1864  Bergheimer Straße B37          7 2022-11-09  2022     11    Wednesday
# 1865  Bergheimer Straße B37          7 2022-11-09  2022     11    Wednesday
# 1866  Bergheimer Straße B37          7 2022-11-09  2022     11    Wednesday
# 1867  Bergheimer Straße B37          7 2022-11-09  2022     11    Wednesday
# 1886  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1887  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1888  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1889  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1890  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1891  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1892  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1893  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1894  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1895  Bergheimer Straße B37          0 2022-11-09  2022     11    Wednesday
# 1896  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1897  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1898  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1899  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1900  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1901  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1902  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1903  Bergheimer Straße B37          1 2022-11-09  2022     11    Wednesday
# 1904  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1905  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1906  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1907  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1908  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1909  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1910  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1911  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1912  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1913  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1914  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1915  Bergheimer Straße B37          2 2022-11-09  2022     11    Wednesday
# 1916  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1917  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1918  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1919  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1920  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1921  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1922  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1923  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1924  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1925  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1926  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday
# 1927  Bergheimer Straße B37          3 2022-11-09  2022     11    Wednesday

# %%
data_timegrouped = data.groupby('dateObserved')[['intensity']].sum()
data_timegrouped
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity
# dateObserved
# 2022-11-03 13:55:00+00:00        338
# 2022-11-03 14:10:00+00:00        371
# 2022-11-03 14:25:00+00:00        404
# 2022-11-03 14:40:00+00:00        383
# 2022-11-03 14:55:00+00:00        426
# ...                              ...
# 2024-02-01 08:10:00+00:00         74
# 2024-02-01 08:25:00+00:00         85
# 2024-02-01 08:40:00+00:00         76
# 2024-02-01 08:55:00+00:00         73
# 2024-02-01 09:10:00+00:00         31
#
# [33829 rows x 1 columns]

# %%
gap = data_timegrouped.asfreq('15min')
gap.isna().sum()
# Out:
# intensity    9870
# dtype: int64

# %%
mask = gap.isna().any(axis=1)
gap_final = gap.loc[mask,'intensity']
gap_final = pd.DataFrame(gap_final)
gap_final
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity
# dateObserved
# 2022-11-03 15:55:00+00:00        NaN
# 2022-11-04 10:55:00+00:00        NaN
# 2022-11-07 01:25:00+00:00        NaN
# 2022-11-08 00:25:00+00:00        NaN
# 2022-11-09 04:55:00+00:00        NaN
# ...                              ...
# 2024-02-01 01:10:00+00:00        NaN
# 2024-02-01 01:40:00+00:00        NaN
# 2024-02-01 02:25:00+00:00        NaN
# 2024-02-01 02:55:00+00:00        NaN
# 2024-02-01 03:40:00+00:00        NaN
#
# [9870 rows x 1 columns]

# %% [markdown]
# Two possible scenarios for NA's:
#
# * Isolated
# * Several consecutive NA's
#
# **Isolated**
#
# 1. Replace the NA with the mean between the previous and the next value.
# 2. Replace the NA with the last value
# 3. .interpolate() (fit a linear model in gap to predict the NAs
#
# **Several consecutive NA's**
#
# 1. Repeat the time-series with past values in the same period
# 2. Randomize the values over the same period. (Compute the histogram of the values at the same period)

# %%
gap_reset = gap.reset_index()
gap_reset['dateObserved'] = pd.to_datetime(gap_reset['dateObserved'])
gap_reset['date']=gap_reset['dateObserved'].dt.date

# %%
gap_reset['date'].min()
# Out:
# datetime.date(2022, 11, 3)

# %%
# e Matplotlib, the underlying library used by Seaborn for plotting, does not inherently understand Python datetime.
#date objects for x-axis values. When it encounters datetime.date objects, it defaults to plotting them as if they were 
#numerical values starting from the Unix epoch (January 1, 1970). This is why your dates are not appearing as expected.

plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.lineplot(x='date', y='intensity', data=gap_reset)
plt.title("Traffic Intensity Throughout the Day, 2022- 2023")
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()

# %%
gap_reset['date'] = pd.to_datetime(gap_reset['dateObserved']).dt.normalize()

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='intensity', data=gap_reset)
plt.title("Traffic Intensity Throughout the Day, 2022-2023")
plt.xlabel('Date')
plt.ylabel('Average Traffic Intensity')
# Out:
# Text(0, 0.5, 'Average Traffic Intensity')

# %%
plt.plot(gap_reset.date, gap_reset.intensity)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

plot = sns.lineplot( x='date', y='intensity', data=gap_reset, hue = gap_reset["intensity"].isna().cumsum(),
                    palette=["blue"]*sum(gap_reset["intensity"].isna()),legend=False, markers= False)

ax.set_xticklabels([])

plt.show()
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_5525/1967826269.py:3: UserWarning:
# The palette list has fewer values (9870) than needed (9871) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.lineplot( x='date', y='intensity', data=gap_reset, hue = gap_reset["intensity"].isna().cumsum(),

# %% [markdown]
# #### gap handling :
# first we remove the big gap before the 2023, as we have a whole year to continue with the prediction.

# %%
data.shape
# Out:
# (116471, 16)

# %%
data2022 = data[data['year'] == 2022]
datafil = data[(data['year'] == 2023) | (data['year'] == 2024)]

datafil_grouped_23_24 = datafil.groupby('dateObserved')[['intensity']].sum()
gap_23_24 = datafil_grouped_23_24.asfreq('15min')
print(f' After focusing on 2023,2024 the data has {gap_23_24.isna().sum().iloc[0]} gaps.')
# Out:
#  After focusing on 2023,2024 the data has 5160 gaps.

# %%
data.dtypes
# Out:
# _id                               int64
# recvTime            datetime64[ns, UTC]
# latitude                        float64
# postalCode                        int64
# vehicleType                      object
# longitude                       float64
# dateObservedTo      datetime64[ns, UTC]
# dateObserved        datetime64[ns, UTC]
# dateObservedFrom    datetime64[ns, UTC]
# intensity                         int64
# streetAddress                    object
# hourOfDay                         int32
# date                     datetime64[ns]
# year                              int32
# month                             int32
# days_of_week                     object
# dtype: object

# %%
data
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#            _id                         recvTime   latitude  postalCode  \
# 0            1 2022-11-03 14:05:24.567000+00:00  49.408167       69115
# 1            2 2022-11-03 14:05:24.617000+00:00  49.408167       69115
# 2            3 2022-11-03 14:05:24.666000+00:00  49.408167       69115
# 3            4 2022-11-03 14:05:24.666000+00:00  49.408167       69115
# 4            5 2022-11-03 14:15:20.829000+00:00  49.408167       69115
# ...        ...                              ...        ...         ...
# 116466  116883 2024-02-01 09:00:21.544000+00:00  49.408167       69115
# 116467  116884 2024-02-01 09:15:21.380000+00:00  49.408167       69115
# 116468  116885 2024-02-01 09:15:21.666000+00:00  49.408167       69115
# 116469  116886 2024-02-01 09:15:21.872000+00:00  49.408167       69115
# 116470  116887 2024-02-01 09:15:22.880000+00:00  49.408167       69115
#
#        vehicleType  longitude            dateObservedTo  \
# 0              car    8.66825 2022-11-03 13:55:00+00:00
# 1       motorcycle    8.66825 2022-11-03 13:55:00+00:00
# 2              van    8.66825 2022-11-03 13:55:00+00:00
# 3            lorry    8.66825 2022-11-03 13:55:00+00:00
# 4              car    8.66825 2022-11-03 14:10:00+00:00
# ...            ...        ...                       ...
# 116466       lorry    8.66825 2024-02-01 08:55:00+00:00
# 116467         car    8.66825 2024-02-01 09:10:00+00:00
# 116468  motorcycle    8.66825 2024-02-01 09:10:00+00:00
# 116469         van    8.66825 2024-02-01 09:10:00+00:00
# 116470       lorry    8.66825 2024-02-01 09:10:00+00:00
#
#                     dateObserved          dateObservedFrom  intensity  \
# 0      2022-11-03 13:55:00+00:00 2022-11-03 13:40:00+00:00        243
# 1      2022-11-03 13:55:00+00:00 2022-11-03 13:40:00+00:00          5
# 2      2022-11-03 13:55:00+00:00 2022-11-03 13:40:00+00:00         44
# 3      2022-11-03 13:55:00+00:00 2022-11-03 13:40:00+00:00         46
# 4      2022-11-03 14:10:00+00:00 2022-11-03 13:55:00+00:00        273
# ...                          ...                       ...        ...
# 116466 2024-02-01 08:55:00+00:00 2024-02-01 08:40:00+00:00         10
# 116467 2024-02-01 09:10:00+00:00 2024-02-01 08:55:00+00:00         22
# 116468 2024-02-01 09:10:00+00:00 2024-02-01 08:55:00+00:00          2
# 116469 2024-02-01 09:10:00+00:00 2024-02-01 08:55:00+00:00          4
# 116470 2024-02-01 09:10:00+00:00 2024-02-01 08:55:00+00:00          3
#
#                 streetAddress  hourOfDay       date  year  month days_of_week
# 0       Bergheimer Straße B37         13 2022-11-03  2022     11     Thursday
# 1       Bergheimer Straße B37         13 2022-11-03  2022     11     Thursday
# 2       Bergheimer Straße B37         13 2022-11-03  2022     11     Thursday
# 3       Bergheimer Straße B37         13 2022-11-03  2022     11     Thursday
# 4       Bergheimer Straße B37         14 2022-11-03  2022     11     Thursday
# ...                       ...        ...        ...   ...    ...          ...
# 116466  Bergheimer Straße B37          8 2024-02-01  2024      2     Thursday
# 116467  Bergheimer Straße B37          9 2024-02-01  2024      2     Thursday
# 116468  Bergheimer Straße B37          9 2024-02-01  2024      2     Thursday
# 116469  Bergheimer Straße B37          9 2024-02-01  2024      2     Thursday
# 116470  Bergheimer Straße B37          9 2024-02-01  2024      2     Thursday
#
# [116471 rows x 16 columns]

# %%
data2022 = data[data['year'] == 2022]
datafil = data[(data['year'] == 2023) | (data['year'] == 2024) & (data['date'] < '2024-01-03')]

datafil_grouped_23_24 = datafil.groupby('dateObserved')[['intensity']].sum()
gap_23_24 = datafil_grouped_23_24.asfreq('15min')
print(f' After reducing the cycle to one year ( 2023/01/03 - 2024/01-02) the data has {gap_23_24.isna().sum().iloc[0]} gaps.')
# Out:
#  After reducing the cycle to one year ( 2023/01/03 - 2024/01-02) the data has 4620 gaps.

# %%
plt.figure(figsize=(20,8))
plt.plot(gap_23_24.index, gap_23_24.intensity)
plt.show()

# %%
gap_23_24
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity
# dateObserved
# 2023-01-03 13:40:00+00:00      166.0
# 2023-01-03 13:55:00+00:00      152.0
# 2023-01-03 14:10:00+00:00      183.0
# 2023-01-03 14:25:00+00:00      201.0
# 2023-01-03 14:40:00+00:00      233.0
# ...                              ...
# 2024-01-02 22:55:00+00:00        3.0
# 2024-01-02 23:10:00+00:00        1.0
# 2024-01-02 23:25:00+00:00        1.0
# 2024-01-02 23:40:00+00:00        NaN
# 2024-01-02 23:55:00+00:00        1.0
#
# [34986 rows x 1 columns]

# %% [raw]
# #For aggregation functions (like sum(), mean(), apply()), setting axis=0 means the operation is performed down each column
# #(i.e., it aggregates rows for each column),
# #and axis=1 means the operation is performed across each row (i.e., it aggregates across the columns in a row).
# # function did not work
# def fill_with_previous_week(row, df):
#     '''
#     takes the
#     '''
#     # If not NaN, just return the original value
#     if not pd.isna(row['intensity']):
#         return row['intensity']
#     # Find the datetime one week prior
#     target_date = row.name - pd.DateOffset(weeks=1)
#     # matching datetime with the same hour, minute, and weekday
#     match = df[(df.index.hour == target_date.hour) &
#                (df.index.minute == target_date.minute) &
#                (df.index.weekday == target_date.weekday)]
#     if not match.empty:
#         return match['intensity'].iloc[-1]  # Return the most recent match's intensity
#
#     else:
#         target_date = row.name - pd.DateOffset(month=1)
#         match = df[(df.index.hour == target_date.hour) &
#         (df.index.minute == target_date.minute) &
#         (df.index.weekday == target_date.weekday)]
#         if not match.empty:
#             return match['intensity'].iloc[-1]
#         else:
#             return np.nan
#
# gap_23_24['filled_intensity'] = gap_23_24.apply(fill_with_previous_week, df=gap_23_24, axis=1)

# %%
def fill_with_previous_week(row, df):
    if pd.isna(row['intensity']):
        target_date = row.name - pd.DateOffset(weeks=1)
        print("Target Date:", target_date)  # Debug print

        match = df[(df.index.hour == target_date.hour) & 
                   (df.index.minute == target_date.minute) & 
                   (df.index.weekday == target_date.weekday())]

        print("Matches found:", len(match))  # Debug print

        if not match.empty:
            return match['intensity'].iloc[-1]
        else:
            return np.nan
    else:
        return row['intensity']

# %%
gap_23_24['filled_intensity'] = gap_23_24.apply(lambda row: fill_with_previous_week(row, gap_23_24), axis=1)
# Out:
# Target Date: 2022-12-28 00:40:00+00:00
# Matches found: 52
# Target Date: 2022-12-28 01:55:00+00:00
# Matches found: 52
# Target Date: 2022-12-28 02:10:00+00:00
# Matches found: 52
# Target Date: 2022-12-28 02:25:00+00:00
# Matches found: 52
# Target Date: 2022-12-28 02:55:00+00:00
# Matches found: 52
# Target Date: 2022-12-29 01:10:00+00:00
# Matches found: 52
# Target Date: 2022-12-29 01:40:00+00:00
# Matches found: 52
# Target Date: 2022-12-29 03:10:00+00:00
# Matches found: 52
# Target Date: 2022-12-30 00:40:00+00:00
# Matches found: 52
# Target Date: 2022-12-30 03:40:00+00:00
# Matches found: 52
# Target Date: 2022-12-31 02:10:00+00:00
# Matches found: 52
# Target Date: 2022-12-31 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-01 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-01 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-02 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-02 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-02 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-02 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-02 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-03 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-03 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-03 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-03 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-04 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-04 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-04 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-04 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-05 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-05 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-05 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-06 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-06 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-09 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-09 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-09 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-11 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-11 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-12 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-12 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-12 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-13 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-13 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-14 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-15 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-15 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-15 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-16 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-17 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-17 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-17 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-17 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-17 21:40:00+00:00
# Matches found: 53
# Target Date: 2023-01-18 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 19:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-18 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-19 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-20 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 19:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-21 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 19:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-22 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-23 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-24 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-25 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-26 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-27 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-28 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-29 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-29 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-30 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-31 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-31 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-01-31 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-01-31 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-01-31 15:10:00+00:00
# Matches found: 53
# Target Date: 2023-01-31 21:25:00+00:00
# Matches found: 53
# Target Date: 2023-01-31 22:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-01 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-01 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-02 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-02 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-02 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-03 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-03 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-03 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-03 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-03 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-04 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-04 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-05 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-05 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-05 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-05 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-05 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-06 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-07 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-07 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-07 16:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-08 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-08 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-08 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-08 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-09 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-10 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-12 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-12 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-13 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-13 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-13 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-13 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-13 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-15 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-15 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-16 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-16 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-18 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-19 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-20 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-21 13:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 13:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 14:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 14:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 14:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 14:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 15:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 15:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 15:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 15:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 16:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 16:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 16:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 16:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 17:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 17:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 17:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 17:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 18:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 18:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 18:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 18:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 19:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 19:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 19:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 19:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 20:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 20:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 20:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 20:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 21:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 21:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 21:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 21:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 22:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 22:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 22:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 22:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 23:10:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 23:25:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 23:40:00+00:00
# Matches found: 53
# Target Date: 2023-02-21 23:55:00+00:00
# Matches found: 53
# Target Date: 2023-02-22 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-22 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-02-23 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-23 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-23 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-24 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-27 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-02-27 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-28 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-02-28 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-01 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-01 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-01 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-02 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-02 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-02 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-03 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-03 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-03 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-04 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-06 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-07 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-09 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-09 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-10 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-12 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-13 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-15 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-15 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-15 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-16 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-17 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-18 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-18 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-21 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-21 23:55:00+00:00
# Matches found: 53
# Target Date: 2023-03-22 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-22 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-22 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-22 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-23 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-23 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-23 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-23 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-23 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-24 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-24 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-24 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-03-24 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-26 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-26 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-27 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-27 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-28 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-28 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-28 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-03-28 23:55:00+00:00
# Matches found: 53
# Target Date: 2023-03-29 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-03-29 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-03-29 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-04-03 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-04-06 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-06 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-10 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-13 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-14 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-04-14 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-14 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-04-19 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-04-20 16:55:00+00:00
# Matches found: 52
# ...
# Matches found: 52
# Target Date: 2023-12-10 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 08:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 09:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 09:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 09:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 09:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 10:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 19:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-10 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 10:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 10:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 10:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 11:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 11:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 15:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 15:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 15:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 15:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 16:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 16:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 16:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 16:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 17:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 17:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 17:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 17:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 18:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 18:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 18:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 18:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 19:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 19:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 19:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 19:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 20:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 20:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 20:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 20:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 21:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 21:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 21:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 21:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 22:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 22:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 22:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 22:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 23:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-11 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 01:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 05:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 06:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 06:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 07:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 07:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 07:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 07:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 08:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-12 08:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 11:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 11:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 12:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 12:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 12:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 12:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 13:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 13:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 13:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 13:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 14:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 14:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 14:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-13 14:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-14 00:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-14 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-14 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-14 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-15 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-15 08:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-16 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-16 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-16 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-16 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 05:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-17 23:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-18 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 02:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 04:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 05:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 05:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-19 06:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-20 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-20 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 02:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-21 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-23 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-23 23:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 01:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 03:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 03:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 04:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 04:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 04:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-24 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-25 06:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-25 23:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 00:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 00:25:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 00:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 01:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 01:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 02:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 02:55:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 03:10:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 03:40:00+00:00
# Matches found: 52
# Target Date: 2023-12-26 23:40:00+00:00
# Matches found: 53

# %%
gap_23_24['filled_intensity'].isna().sum()
# Out:
# 373

# %%
gap_23_24
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity  filled_intensity
# dateObserved
# 2023-01-03 13:40:00+00:00      166.0             166.0
# 2023-01-03 13:55:00+00:00      152.0             152.0
# 2023-01-03 14:10:00+00:00      183.0             183.0
# 2023-01-03 14:25:00+00:00      201.0             201.0
# 2023-01-03 14:40:00+00:00      233.0             233.0
# ...                              ...               ...
# 2024-01-02 22:55:00+00:00        3.0               3.0
# 2024-01-02 23:10:00+00:00        1.0               1.0
# 2024-01-02 23:25:00+00:00        1.0               1.0
# 2024-01-02 23:40:00+00:00        NaN               NaN
# 2024-01-02 23:55:00+00:00        1.0               1.0
#
# [34986 rows x 2 columns]

# %%
mask = gap_23_24['filled_intensity'].isna()
gap_23_24_null = gap_23_24.loc[mask]
gap_23_24_null
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity  filled_intensity
# dateObserved
# 2023-01-05 01:10:00+00:00        NaN               NaN
# 2023-01-05 01:40:00+00:00        NaN               NaN
# 2023-01-10 00:55:00+00:00        NaN               NaN
# 2023-01-10 01:10:00+00:00        NaN               NaN
# 2023-01-12 02:25:00+00:00        NaN               NaN
# ...                              ...               ...
# 2024-01-02 02:40:00+00:00        NaN               NaN
# 2024-01-02 02:55:00+00:00        NaN               NaN
# 2024-01-02 03:10:00+00:00        NaN               NaN
# 2024-01-02 03:40:00+00:00        NaN               NaN
# 2024-01-02 23:40:00+00:00        NaN               NaN
#
# [373 rows x 2 columns]

# %%
gap_23_24['ffill_intenstiy']= gap_23_24['intensity'].ffill()
gap_23_24['bfil_intensity']=gap_23_24['intensity'].bfill()

# %%
mask = gap_23_24.filled_intensity.isna()
null = gap_23_24.loc[mask,:]
null
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            intensity  filled_intensity  ffill_intenstiy  \
# dateObserved
# 2023-01-05 01:10:00+00:00        NaN               NaN              4.0
# 2023-01-05 01:40:00+00:00        NaN               NaN              3.0
# 2023-01-10 00:55:00+00:00        NaN               NaN              1.0
# 2023-01-10 01:10:00+00:00        NaN               NaN              1.0
# 2023-01-12 02:25:00+00:00        NaN               NaN              2.0
# ...                              ...               ...              ...
# 2024-01-02 02:40:00+00:00        NaN               NaN              2.0
# 2024-01-02 02:55:00+00:00        NaN               NaN              2.0
# 2024-01-02 03:10:00+00:00        NaN               NaN              2.0
# 2024-01-02 03:40:00+00:00        NaN               NaN              3.0
# 2024-01-02 23:40:00+00:00        NaN               NaN              1.0
#
#                            bfil_intensity
# dateObserved
# 2023-01-05 01:10:00+00:00             3.0
# 2023-01-05 01:40:00+00:00             2.0
# 2023-01-10 00:55:00+00:00             2.0
# 2023-01-10 01:10:00+00:00             2.0
# 2023-01-12 02:25:00+00:00             2.0
# ...                                   ...
# 2024-01-02 02:40:00+00:00             3.0
# 2024-01-02 02:55:00+00:00             3.0
# 2024-01-02 03:10:00+00:00             3.0
# 2024-01-02 03:40:00+00:00             3.0
# 2024-01-02 23:40:00+00:00             1.0
#
# [373 rows x 4 columns]

# %%
gap_23_24['filled_intensity'] = gap_23_24['filled_intensity'].ffill()

# %%
gap_23_24= gap_23_24.drop(columns = ['ffill_intenstiy','bfil_intensity'])
gap_23_24.isna().sum()
# Out:
# intensity           4620
# filled_intensity       0
# dtype: int64

# %% [markdown]
# ### seperation of Ml and EDA datasets

# %%
data_preprocessed = gap_23_24.reset_index()
data_preprocessed.dtypes
# Out:
# dateObserved        datetime64[ns, UTC]
# intensity                       float64
# filled_intensity                float64
# dtype: object

# %%
data_ml = gap_23_24.drop(columns = 'intensity')
data_ml
# Out:
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# /Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/Finalproject/envfp/lib/python3.11/site-packages/IPython/core/formatters.py:347: FutureWarning: DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#                            filled_intensity
# dateObserved
# 2023-01-03 13:40:00+00:00             166.0
# 2023-01-03 13:55:00+00:00             152.0
# 2023-01-03 14:10:00+00:00             183.0
# 2023-01-03 14:25:00+00:00             201.0
# 2023-01-03 14:40:00+00:00             233.0
# ...                                     ...
# 2024-01-02 22:55:00+00:00               3.0
# 2024-01-02 23:10:00+00:00               1.0
# 2024-01-02 23:25:00+00:00               1.0
# 2024-01-02 23:40:00+00:00               1.0
# 2024-01-02 23:55:00+00:00               1.0
#
# [34986 rows x 1 columns]

# %% [markdown]
# ### Frequcney Week

# %%
#quarterly frequency, year ends in December: ‘QE’
data_mlw = data_ml.asfreq('W') # weekly frequency

# Train-test dates
# ======================================================================================
iloc_TrainEnd =int(data_mlw.shape[0] - np.ceil(data_mlw.shape[0]*0.2))
print(f"Train dates : {data_mlw.index.min()} --- {data_mlw.iloc[:iloc_TrainEnd].index.max()}  (n={len(data_mlw.iloc[:iloc_TrainEnd])})")
print(f"Test dates  : {data_mlw.iloc[iloc_TrainEnd:].index.min()} --- {data_mlw.iloc[:].index.max()}  (n={len(data_mlw.iloc[iloc_TrainEnd:])})")
data_train = data_mlw.iloc[:iloc_TrainEnd]
data_test  = data_mlw.iloc[iloc_TrainEnd:]
# Out:
# Train dates : 2023-01-08 13:40:00+00:00 --- 2023-10-15 13:40:00+00:00  (n=41)
# Test dates  : 2023-10-22 13:40:00+00:00 --- 2023-12-31 13:40:00+00:00  (n=11)

# %%
fig, ax=plt.subplots(figsize=(20,8))
data_train.plot(ax=ax, label='train')
data_test.plot(ax=ax, label='test')
ax.set_title('weekly intensity')
ax.legend();

# %% [markdown]
# #### Exploratory Analysis (F:w) :

# %% [raw]
# Stationarity: Stationarity means that the statistical properties (mean, variance...) remain constant over time, so time series with trends or seasonality are not stationary. Since ARIMA assumes the stationarity of the data, it is essential to subject the data to rigorous tests, such as the Augmented Dickey-Fuller test, to assess stationarity. If non-stationarity is found, the series should be differenced until stationarity is achieved. This analysis helps to determine the optimal value of the parameter  𝑑 .
# **ARIMA assumes the stationarity of the data***

# %% [raw]
# Autocorrelation analysis: Plot the autocorrelation and partial autocorrelation functions (ACF and PACF) to identify potential lag relationships between data points. This visual analysis provides insight into determining appropriate autoregressive (AR) and moving average (MA) terms ( 𝑝  and  𝑞 ) for the ARIMA model.

# %% [raw]
# Seasonal decomposition: In cases where seasonality is suspected, decomposing the series into trend, seasonal, and residual components using techniques such as moving averages or seasonal time series decomposition (STL) can reveal hidden patterns and help identify seasonality. This analysis helps to determine the optimal values of the parameters  𝑃 ,  𝐷 ,  𝑄  and  𝑚 .

# %% [markdown]
# #### Stationarity Anslysis:
# using the Augmented Dickey-Fuller (ADF) test and the Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test:

# %% [markdown]
# **KPSS test** focuses on the presence of trends, and a low p-value indicates non-stationarity due to a trend.
# <br>**ADF test** focuses on the presence of a unit root, and a low p-value indicates that the time series does not have a unit root, suggesting it might be stationary.

# %%
# Test stationarity
# ==============================================================================
warnings.filterwarnings("ignore")

data_diff_1 = data_train.diff().dropna()
data_diff_2 = data_diff_1.diff().dropna()

print('Test stationarity for original series')
print('-------------------------------------')
adfuller_result = adfuller(data_mlw)
kpss_result = kpss(data_mlw)
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

print('\nTest stationarity for differenced series (order=1)')
print('--------------------------------------------------')
adfuller_result = adfuller(data_diff_1)
kpss_result = kpss(data_mlw.diff().dropna())
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

print('\nTest stationarity for differenced series (order=2)')
print('--------------------------------------------------')
adfuller_result = adfuller(data_diff_2)
kpss_result = kpss(data_mlw.diff().diff().dropna())
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

warnings.filterwarnings("default")

# Plot series
# ==============================================================================
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(7, 5), sharex=True)
data_mlw.plot(ax=axs[0], title='Original time series')
data_diff_1.plot(ax=axs[1], title='Differenced order 1')
data_diff_2.plot(ax=axs[2], title='Differenced order 2');
# Out:
# Test stationarity for original series
# -------------------------------------
# ADF Statistic: -2.185265687404781, p-value: 0.21163655728347447
# KPSS Statistic: 0.3719924421494983, p-value: 0.08922739562521625
#
# Test stationarity for differenced series (order=1)
# --------------------------------------------------
# ADF Statistic: -3.6652076544297056, p-value: 0.004630024218400591
# KPSS Statistic: 0.17493526588650493, p-value: 0.1
#
# Test stationarity for differenced series (order=2)
# --------------------------------------------------
# ADF Statistic: -8.339742039810474, p-value: 3.19999990714707e-13
# KPSS Statistic: 0.5000000000000089, p-value: 0.04166666666666467

# %% [markdown]
# #### Test Result
# This tests provide insights into the time series' properties.
#
#
# **Original Series**
# <br>**ADF Statistic: -2.3655, p-value: 0.1517**
# The ADF test is used to test for the presence of unit root, a sign of non-stationarity. A more negative statistic indicates stronger evidence against the null hypothesis of a unit root (non-stationarity). Here, the p-value is above 0.05, suggesting that you fail to reject the null hypothesis. This implies that the series is non-stationary as per the ADF test.
# <br>**KPSS Statistic: 1.1576, p-value: 0.01**
# The KPSS test is used to test for the presence of stationarity. Under the null hypothesis, the series is stationary. Given the p-value is less than 0.05, you reject the null hypothesis, implying the series is not stationary.
# These results suggest that the original series is not stationary, both according to the ADF (which suggests presence of a unit root) and the KPSS tests (which suggests trend-stationarity is not present).
#
#
# **Differenced Series (Order 1)**
# <br>**ADF Statistic: -8.0939, p-value: ~0**
# The ADF test now shows a very negative statistic with a p-value effectively zero, indicating strong evidence against the null hypothesis of a unit root. This suggests the series has become stationary after one differencing.
# <br>**KPSS Statistic: 0.0541, p-value: 0.1**
# The KPSS test p-value is above 0.05, indicating failure to reject the null hypothesis of stationarity. This confirms that the first differenced series is stationary.
#
#
# **Differenced Series (Order 2)**
# <br>**ADF Statistic: -9.6139, p-value: ~0**
# Similarly to the first differencing, the second differencing ADF result is highly negative with a p-value close to zero, which strongly rejects the null hypothesis of a unit root. This indicates the series remains stationary or becomes even more clearly stationary.
# <br>**KPSS Statistic: 0.0467, p-value: 0.1**
# The KPSS test results continue to suggest stationarity since the p-value is again above 0.05, supporting the null hypothesis of stationarity.
#
# **Interpretation and Next Steps**
#
# **Overall Analysis:** After checking the first and second-order differences, the p-value indicates a statistically significant decrease below the widely-recognized and accepted threshold of 0.05 for order=1. The first differencing is sufficient to achieve stationarity based on both tests. **Therefore, the most appropriate selection for the ARIMA parameter  d  is 1.** As the first differencing has already stabilized the mean and variance,there is  no need to go to second differencing, as excessive differencing can lead to over-differencing, where the series may start showing artificial patterns.
#
# **Model Building:** With the first differenced series confirmed stationary, you can proceed to build time series forecasting models such as ARIMA, **specifying d=1** for the differencing order in an ARIMA model or D=1 in a seasonal order of a SARIMA or SARIMAX model if seasonal patterns are also considered.
#
# **Visual Check:** The plots show a visibly more stable mean and variance in the first and second differenced series compared to the original series, aligning with our statistical tests.

# %% [markdown]
# #### Autocorrelation Analysis

# %% [raw]
# Plotting the autocorrelation function (ACF) and partial autocorrelation function (PACF) of the time series can provide insight into the appropriate values for  𝑝  and  𝑞 . The ACF helps in identifying the value of  𝑞  (lag in the moving average part), while the PACF assists in identifying the value of  𝑝  (lag in the autoregressive part).

# %% [markdown]
# Since the **Stationarity Analysis** indicates that **differencing is required**, subsequent analyses should be conducted using the differenced series, as this will align with the manner in which the ARIMA model interprets the series.

# %% [raw]
# Autocorrelation Function (ACF)
#
# The ACF calculates the correlation between a time series and its lagged values. Within the context of ARIMA modeling, a sharp drop-off in the ACF after a few lags indicates that the data have a finite autoregressive order. The lag at which the ACF drops off provides an estimation of the value of  𝑞 . If the ACF displays a sinusoidal or damped sinusoidal pattern, it suggests seasonality is present and requires consideration of seasonal orders in addition to non-seasonal orders.
#
# Partial Autocorrelation Function (PACF)
#
# The PACF measures the correlation between a lagged value and the current value of the time series, while accounting for the effect of the intermediate lags. In the context of ARIMA modeling, if the PACF sharply cuts off after a certain lag, while the remaining values are within the confidence interval, it suggests an AR model of that order. The lag, at which the PACF cuts off, gives an idea of the value of  𝑝 .

# %% [raw]
# Some rules of thumb are:
# Take the order of AR term p to be equal to as many lags that crosses the significance limit in the PACF plot.
#
# Take the order of MA term q to be equal to as many lags that crosses the significance limit in the ACF plot.
#
# If the ACF cuts off at lag q and the PACF cuts off at lag p, one could start with an ARIMA(p, d, q) model.
#
# If only the PACF stops after lag p, one could start with an AR(p) model.
#
# If only the ACF stops after lag q, one could start with an MA(q) model.

# %%
# Autocorrelation plot for original and differenced series
# ==============================================================================
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(7, 4), sharex=True)
plot_acf(data_mlw, ax=axs[0], lags=20, alpha=0.05) # Using 20 lags for weekly data
axs[0].set_title('Autocorrelation original series')
plot_acf(data_diff_1, ax=axs[1], lags=20, alpha=0.05)  #Using 20 lags for weekly data
axs[1].set_title('Autocorrelation differenced series (order=1)');

# %%
# Partial autocorrelation plot for original and differenced series
# ==============================================================================
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(7, 3), sharex=True)
plot_pacf(data_mlw, ax=axs[0], lags=20, alpha=0.05)
axs[0].set_title('Partial autocorrelation original series')
plot_pacf(data_diff_1, ax=axs[1], lags=20, alpha=0.05)
axs[1].set_title('Partial autocorrelation differenced series (order=1)');
plt.tight_layout();

# %% [markdown]
# #### Question !!
# **?? No sharp drop-off?? ACF displays a sinusoidal pattern, it suggests seasonality is present and requires consideration of seasonal orders in addition to non-seasonal orders.??

# %% [raw]
# ### x must have 2 complete cycles requires 104 observations. x only has 52 observation(s)
# # Time series descoposition of original versus differenced series
# # ==============================================================================
# res_decompose = seasonal_decompose(data_mlw, model='additive', extrapolate_trend='freq')
# res_descompose_diff_1 = seasonal_decompose(data_diff_1, model='additive', extrapolate_trend='freq')
#
# fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(9, 6), sharex=True)
#
# res_decompose.observed.plot(ax=axs[0, 0])
# axs[0, 0].set_title('Original series')
# res_decompose.trend.plot(ax=axs[1, 0])
# axs[1, 0].set_title('Trend')
# res_decompose.seasonal.plot(ax=axs[2, 0])
# axs[2, 0].set_title('Seasonal')
# res_decompose.resid.plot(ax=axs[3, 0])
# axs[3, 0].set_title('Residuals')
# res_descompose_diff_1.observed.plot(ax=axs[0, 1])
# axs[0, 1].set_title('Differenced series (order=1)')
# res_descompose_diff_1.trend.plot(ax=axs[1, 1])
# axs[1, 1].set_title('Trend')
# res_descompose_diff_1.seasonal.plot(ax=axs[2, 1])
# axs[2, 1].set_title('Seasonal')
# res_descompose_diff_1.resid.plot(ax=axs[3, 1])
# axs[3, 1].set_title('Residuals')
# fig.suptitle('Time serie decomposition original series versus differenced series', fontsize=14)
# fig.tight_layout();

# %% [markdown]
# ### Frequcney Day

# %%
#quarterly frequency, year ends in December: ‘QE’
data_mld = data_ml.asfreq('D') #dayli

# Train-test dates
# ======================================================================================
iloc_TrainEnd =int(data_mld.shape[0] - np.ceil(data_mld.shape[0]*0.3))
print(f"Train dates : {data_mld.index.min()} --- {data_mld.iloc[:iloc_TrainEnd].index.max()}  (n={len(data_mld.iloc[:iloc_TrainEnd])})")
print(f"Test dates  : {data_mld.iloc[iloc_TrainEnd:].index.min()} --- {data_mld.iloc[:].index.max()}  (n={len(data_mld.iloc[iloc_TrainEnd:])})")
data_trainD = data_mld.iloc[:iloc_TrainEnd]
data_testD  = data_mld.iloc[iloc_TrainEnd:]
# Out:
# Train dates : 2023-01-03 13:40:00+00:00 --- 2023-09-14 13:40:00+00:00  (n=255)
# Test dates  : 2023-09-15 13:40:00+00:00 --- 2024-01-02 13:40:00+00:00  (n=110)

# %%
fig, ax=plt.subplots(figsize=(20,8))
data_trainD.plot(ax=ax, label='train')
data_testD.plot(ax=ax, label='test')
ax.set_title('dayly intensity')
ax.legend();

# %% [markdown]
# #### Exploratory Analysis (F:D) :

# %% [raw]
# Stationarity: Stationarity means that the statistical properties (mean, variance...) remain constant over time, so time series with trends or seasonality are not stationary. Since ARIMA assumes the stationarity of the data, it is essential to subject the data to rigorous tests, such as the Augmented Dickey-Fuller test, to assess stationarity. If non-stationarity is found, the series should be differenced until stationarity is achieved. This analysis helps to determine the optimal value of the parameter  𝑑 .
# **ARIMA assumes the stationarity of the data***

# %% [raw]
# Autocorrelation analysis: Plot the autocorrelation and partial autocorrelation functions (ACF and PACF) to identify potential lag relationships between data points. This visual analysis provides insight into determining appropriate autoregressive (AR) and moving average (MA) terms ( 𝑝  and  𝑞 ) for the ARIMA model.

# %% [raw]
# Seasonal decomposition: In cases where seasonality is suspected, decomposing the series into trend, seasonal, and residual components using techniques such as moving averages or seasonal time series decomposition (STL) can reveal hidden patterns and help identify seasonality. This analysis helps to determine the optimal values of the parameters  𝑃 ,  𝐷 ,  𝑄  and  𝑚 .

# %% [markdown]
# #### Stationarity Anslysis:
# using the Augmented Dickey-Fuller (ADF) test and the Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test:

# %% [markdown]
# **KPSS test** focuses on the presence of trends, and a low p-value indicates non-stationarity due to a trend.
# <br>**ADF test** focuses on the presence of a unit root, and a low p-value indicates that the time series does not have a unit root, suggesting it might be stationary.

# %%
# Test stationarity
# ==============================================================================
warnings.filterwarnings("ignore")

data_diffD_1 = data_trainD.diff().dropna()
data_diffD_2 = data_diffD_1.diff().dropna()

print('Test stationarity for original series')
print('-------------------------------------')
adfuller_result = adfuller(data_mld)
kpss_result = kpss(data_mld)
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

print('\nTest stationarity for differenced series (order=1)')
print('--------------------------------------------------')
adfuller_result = adfuller(data_diffD_1)
kpss_result = kpss(data_mld.diff().dropna())
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

print('\nTest stationarity for differenced series (order=2)')
print('--------------------------------------------------')
adfuller_result = adfuller(data_diffD_2)
kpss_result = kpss(data_mld.diff().diff().dropna())
print(f'ADF Statistic: {adfuller_result[0]}, p-value: {adfuller_result[1]}')
print(f'KPSS Statistic: {kpss_result[0]}, p-value: {kpss_result[1]}')

warnings.filterwarnings("default")

# Plot series
# ==============================================================================
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(7, 5), sharex=True)
data_mld.plot(ax=axs[0], title='Original time series')
data_diffD_1.plot(ax=axs[1], title='Differenced order 1')
data_diffD_2.plot(ax=axs[2], title='Differenced order 2');
# Out:
# Test stationarity for original series
# -------------------------------------
# ADF Statistic: -2.3655168611320856, p-value: 0.15170642820076896
# KPSS Statistic: 1.1575505243562485, p-value: 0.01
#
# Test stationarity for differenced series (order=1)
# --------------------------------------------------
# ADF Statistic: -7.506355579591736, p-value: 4.124770840532069e-11
# KPSS Statistic: 0.0541124833253827, p-value: 0.1
#
# Test stationarity for differenced series (order=2)
# --------------------------------------------------
# ADF Statistic: -8.825012184481906, p-value: 1.8335693695262805e-14
# KPSS Statistic: 0.04667119604612603, p-value: 0.1

# %% [markdown]
# #### Test Result
# This tests provide insights into the time series' properties.
#
#
# **Original Series**
# <br>**ADF Statistic: -2.3655, p-value: 0.1517**
# The ADF test is used to test for the presence of unit root, a sign of non-stationarity. A more negative statistic indicates stronger evidence against the null hypothesis of a unit root (non-stationarity). Here, the p-value is above 0.05, suggesting that you fail to reject the null hypothesis. This implies that the series is non-stationary as per the ADF test.
# <br>**KPSS Statistic: 1.1576, p-value: 0.01**
# The KPSS test is used to test for the presence of stationarity. Under the null hypothesis, the series is stationary. Given the p-value is less than 0.05, you reject the null hypothesis, implying the series is not stationary.
# These results suggest that the original series is not stationary, both according to the ADF (which suggests presence of a unit root) and the KPSS tests (which suggests trend-stationarity is not present).
#
#
# **Differenced Series (Order 1)**
# <br>**ADF Statistic: -8.0939, p-value: ~0**
# The ADF test now shows a very negative statistic with a p-value effectively zero, indicating strong evidence against the null hypothesis of a unit root. This suggests the series has become stationary after one differencing.
# <br>**KPSS Statistic: 0.0541, p-value: 0.1**
# The KPSS test p-value is above 0.05, indicating failure to reject the null hypothesis of stationarity. This confirms that the first differenced series is stationary.
#
#
# **Differenced Series (Order 2)**
# <br>**ADF Statistic: -9.6139, p-value: ~0**
# Similarly to the first differencing, the second differencing ADF result is highly negative with a p-value close to zero, which strongly rejects the null hypothesis of a unit root. This indicates the series remains stationary or becomes even more clearly stationary.
# <br>**KPSS Statistic: 0.0467, p-value: 0.1**
# The KPSS test results continue to suggest stationarity since the p-value is again above 0.05, supporting the null hypothesis of stationarity.
#
# **Interpretation and Next Steps**
#
# **Overall Analysis:** After checking the first and second-order differences, the p-value indicates a statistically significant decrease below the widely-recognized and accepted threshold of 0.05 for order=1. The first differencing is sufficient to achieve stationarity based on both tests. **Therefore, the most appropriate selection for the ARIMA parameter  d  is 1.** As the first differencing has already stabilized the mean and variance,there is  no need to go to second differencing, as excessive differencing can lead to over-differencing, where the series may start showing artificial patterns.
#
# **Model Building:** With the first differenced series confirmed stationary, you can proceed to build time series forecasting models such as ARIMA, **specifying d=1** for the differencing order in an ARIMA model or D=1 in a seasonal order of a SARIMA or SARIMAX model if seasonal patterns are also considered.
#
# **Visual Check:** The plots show a visibly more stable mean and variance in the first and second differenced series compared to the original series, aligning with our statistical tests.

# %% [markdown]
# #### Autocorrelation Analysis

# %% [raw]
# Plotting the autocorrelation function (ACF) and partial autocorrelation function (PACF) of the time series can provide insight into the appropriate values for  𝑝  and  𝑞 . The ACF helps in identifying the value of  𝑞  (lag in the moving average part), while the PACF assists in identifying the value of  𝑝  (lag in the autoregressive part).

# %% [markdown]
# Since the **Stationarity Analysis** indicates that **differencing is required**, subsequent analyses should be conducted using the differenced series, as this will align with the manner in which the ARIMA model interprets the series.

# %% [raw]
# Autocorrelation Function (ACF)
#
# The ACF calculates the correlation between a time series and its lagged values. Within the context of ARIMA modeling, a sharp drop-off in the ACF after a few lags indicates that the data have a finite autoregressive order. The lag at which the ACF drops off provides an estimation of the value of  𝑞 . If the ACF displays a sinusoidal or damped sinusoidal pattern, it suggests seasonality is present and requires consideration of seasonal orders in addition to non-seasonal orders.
#
# Partial Autocorrelation Function (PACF)
#
# The PACF measures the correlation between a lagged value and the current value of the time series, while accounting for the effect of the intermediate lags. In the context of ARIMA modeling, if the PACF sharply cuts off after a certain lag, while the remaining values are within the confidence interval, it suggests an AR model of that order. The lag, at which the PACF cuts off, gives an idea of the value of  𝑝 .

# %% [raw]
# Some rules of thumb are:
# Take the order of AR term p to be equal to as many lags that crosses the significance limit in the PACF plot.
#
# Take the order of MA term q to be equal to as many lags that crosses the significance limit in the ACF plot.
#
# If the ACF cuts off at lag q and the PACF cuts off at lag p, one could start with an ARIMA(p, d, q) model.
#
# If only the PACF stops after lag p, one could start with an AR(p) model.
#
# If only the ACF stops after lag q, one could start with an MA(q) model.

# %%
# Autocorrelation plot for original and differenced series
# ==============================================================================
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(7, 4), sharex=True)
plot_acf(data_mld, ax=axs[0], lags=30, alpha=0.05)
axs[0].set_title('Autocorrelation original series')
plot_acf(data_diffD_1, ax=axs[1], lags=30, alpha=0.05) # 30 lags for daily  giving a view of the past month. 
axs[1].set_title('Autocorrelation differenced series (order=1)');

# %% [markdown]
# #### Question !!
# **?? No sharp drop-off?? ACF displays a sinusoidal pattern, it suggests seasonality is present and requires consideration of seasonal orders in addition to non-seasonal orders.??

# %%
# Partial autocorrelation plot for original and differenced series
# ==============================================================================
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(7, 3), sharex=True)
plot_pacf(data_mld, ax=axs[0], lags=30, alpha=0.05)
axs[0].set_title('Partial autocorrelation original series')
plot_pacf(data_diffD_1, ax=axs[1], lags=30, alpha=0.05)
axs[1].set_title('Partial autocorrelation differenced series (order=1)');
plt.tight_layout();

# %%
# Time series descoposition of original versus differenced series
# ==============================================================================
res_decompose = seasonal_decompose(data_mld, model='additive', extrapolate_trend='freq')
res_descompose_diff_1 = seasonal_decompose(data_diffD_1, model='additive', extrapolate_trend='freq')

fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(9, 6), sharex=True)

res_decompose.observed.plot(ax=axs[0, 0])
axs[0, 0].set_title('Original series')
res_decompose.trend.plot(ax=axs[1, 0])
axs[1, 0].set_title('Trend')
res_decompose.seasonal.plot(ax=axs[2, 0])
axs[2, 0].set_title('Seasonal')
res_decompose.resid.plot(ax=axs[3, 0])
axs[3, 0].set_title('Residuals')
res_descompose_diff_1.observed.plot(ax=axs[0, 1])
axs[0, 1].set_title('Differenced series (order=1)')
res_descompose_diff_1.trend.plot(ax=axs[1, 1])
axs[1, 1].set_title('Trend')
res_descompose_diff_1.seasonal.plot(ax=axs[2, 1])
axs[2, 1].set_title('Seasonal')
res_descompose_diff_1.resid.plot(ax=axs[3, 1])
axs[3, 1].set_title('Residuals')
fig.suptitle('Time serie decomposition original series versus differenced series', fontsize=14)
fig.tight_layout();

# %% [raw]
# from statsmodels.tsa.seasonal import seasonal_decompose
# decompose_data = seasonal_decompose(data_ml['filled_intensity'], model="additive", period=672 )
# decompose_result = decompose_data.plot()
# plt.show()

# %% [raw]
# from statsmodels.tsa.statespace.sarimax import SARIMAX
#
# model = SARIMAX(data_ml['filled_intensity'],
#                 order=(1, 1, 1),                # Example non-seasonal order
#                 seasonal_order=(1, 1, 1, 672),  # Seasonal order (with period 672 for weekly)
#                 enforce_stationarity=False,
#                 enforce_invertibility=False)
#
# results = model.fit(disp=False)
# print(results.summary())

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data_preprocessed['hourOfDay']=data_preprocessed['dateObserved'].dt.hour
data_preprocessed['date']=data_preprocessed['dateObserved'].dt.date
data_preprocessed['date'] = pd.to_datetime(data_preprocessed['date'])
data_preprocessed['year'] = data_preprocessed['date'].dt.year
data_preprocessed['month_number'] = data_preprocessed['date'].dt.month
data_preprocessed['month'] = data_preprocessed['date'].dt.month_name()
data_preprocessed['days_of_week'] = data_preprocessed['date'].dt.day_name()

# %% [markdown]
# #### Traffic intensity variation throughout the day

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.lineplot(x='hourOfDay', y='filled_intensity', data=data_preprocessed, estimator='mean' )
plt.title("Citie's Traffic Intensity Variation Throughout the Day")
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()

#note estimatorname : Method for aggregating across multiple observations of the y variable at the same x level. If None, all observations will be drawn.

# %%
sns.boxplot(data=data, x ='vehicleType' , y='intensity', hue='vehicleType')
# Out:
# <Axes: xlabel='vehicleType', ylabel='intensity'>

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.lineplot(x='hourOfDay', y='intensity', data=data_preprocessed[(data_preprocessed['year']==2023)], estimator='mean')
plt.title('Traffic Intensity Variation Throughout the Day in 2023')
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.lineplot(x='hourOfDay', y='intensity',hue='date', data=data_preprocessed[(data_preprocessed['year']==2024)], estimator='mean')
plt.title('Traffic Intensity Variation  first and second January 2024')
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()

# %%
data_preprocessed.head()
# Out:
#                dateObserved  intensity  filled_intensity  hourOfDay  \
# 0 2023-01-03 13:40:00+00:00      166.0             166.0         13
# 1 2023-01-03 13:55:00+00:00      152.0             152.0         13
# 2 2023-01-03 14:10:00+00:00      183.0             183.0         14
# 3 2023-01-03 14:25:00+00:00      201.0             201.0         14
# 4 2023-01-03 14:40:00+00:00      233.0             233.0         14
#
#         date  year  month_number    month days_of_week
# 0 2023-01-03  2023             1  January      Tuesday
# 1 2023-01-03  2023             1  January      Tuesday
# 2 2023-01-03  2023             1  January      Tuesday
# 3 2023-01-03  2023             1  January      Tuesday
# 4 2023-01-03  2023             1  January      Tuesday

# %%
plt.figure(figsize=(16, 8))
sns.set_style("whitegrid")

sns.lineplot(x='hourOfDay', y='intensity', hue='days_of_week',
             data=data_preprocessed[data_preprocessed['month_number']<=3],
             estimator='mean')

plt.title(f'Traffic Intensity in 2023, First quarter: January – March')
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.legend(title='days_of_week', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.set_style("whitegrid")

sns.lineplot(x='hourOfDay', y='intensity', hue='month',
             data=data_preprocessed[(data_preprocessed['year'] == 2023) &(data_preprocessed['month_number']<=3)],
             estimator='mean')

plt.title(f'Traffic Intensity in 2023, First quarter: January – March')
plt.xlabel('Hour of Day')
plt.ylabel('Average Traffic Intensity')
plt.xticks(range(0, 24))
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [raw]
# data_preprocessed.to_csv('data_bergheim37.csv')

# %% [markdown]
# #### One-hot encoding

# %%
data.vehicleType.unique()

# %%
# One-hot encode 'vehicleType'
encoder = OneHotEncoder(sparse_output=False)
vehicle_type_encoded = encoder.fit_transform(data[['vehicleType']])
vehicle_type_encoded_df = pd.DataFrame(vehicle_type_encoded, columns=encoder.get_feature_names_out(['vehicleType']))

# %%
# One-hot encode locations
encoder = OneHotEncoder(sparse_output=False)
vehicle_type_encoded = encoder.fit_transform(data[['vehicleType']])
vehicle_type_encoded_df = pd.DataFrame(vehicle_type_encoded, columns=encoder.get_feature_names_out(['vehicleType']))

# %%
print(data.index.is_unique)
print(vehicle_type_encoded_df.index.is_unique)

# %%
data_vehicle_encoded= pd.concat([data, vehicle_type_encoded_df], axis=1)

# %% [markdown]
# #### Traffic intensity by vehicleType

# %%
vehicle_types = encoder.categories_[0]
average_intensities = [data_vehicle_encoded.loc[data_vehicle_encoded[vehicle_type] == 1, 'intensity'].mean() for vehicle_type in vehicle_type_encoded_df.columns]
plt.figure(figsize=(12, 6))
sns.barplot(x=vehicle_types, y=average_intensities)
plt.title('Average Traffic Intensity by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average Traffic Intensity')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor, AdaBoostRegressor, RandomForestRegressor

# %% [raw]
# Model Comparison notes :
# Tree-based models (Decision Tree, Random Forest, Bagging with Decision Trees, AdaBoost with Decision Trees) are robust to outliers and do not require feature scaling. They are very good for non-linear data.
# Random Forest and Bagging can help improve the performance and overfitting issues of a single Decision Tree by introducing randomness and creating an ensemble of trees.
# AdaBoost focuses on instances that are harder to predict, potentially offering better performance on more complex datasets.
# KNeighborsRegressor can be sensitive to the scale of the data, hence the normalization. It's better for datasets where the output is a smooth function of the inputs.
# The model with the lowest RMSE and highest R² values typically offers the best performance on test set.
# Tree-based models like Random Forest might generally perform well for complex datasets due to their ability to capture non-linear relationships and interactions between features without needing feature scaling. However,  evaluate each model's performance

# %% [raw]
# Note2 :
# In scikit-learn, the BaggingRegressor and BaggingClassifier are the two main classes used for bagging, depending on the type of problem.
#
# When we use BaggingRegressor or BaggingClassifier without specifying the base estimator, they default to using a Decision Tree.
# For regression, the default is a DecisionTreeRegressor, and for classification, it's a DecisionTreeClassifier.
# This default behavior is designed because Decision Trees are a common and effective choice for the base learners in a bagging ensemble.
#
# However, if we want to use a different model as the base estimator, we can explicitly specify it using the base_estimator parameter.  Example using a K-Nearest Neighbors model as the base estimator in a bagging ensemble for a regression problem
# knn = KNeighborsRegressor()
# # Create a Bagging ensemble using KNN as the base estimator
# bagging_model = BaggingRegressor(base_estimator=knn, n_estimators=10, random_state=10)

# %%
# Preparation 
features = pd.concat([data_preprocessed[['hourOfDay', 'latitude', 'longitude']], vehicle_type_encoded_df], axis=1)
target = data_preprocessed['intensity']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=10)

# %% [markdown]
# ### Tree-based model

# %% [markdown]
# ####  Decision Tree Regressor

# %%
# note no need to normalize

decision_tree_model = DecisionTreeRegressor(random_state=10)
decision_tree_model.fit(X_train, y_train)


y_pred = decision_tree_model.predict(X_test)

# Evaluaton
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}, RMSE: {rmse}, R^2: {r2}')
# Out:
# MSE: 393.2635337007132, RMSE: 19.830873246045247, R^2: 0.66001904219095

# %% [markdown]
# ### Non-tree-based model

# %%
models = {
    'Bagging': BaggingRegressor(random_state=10),
    'AdaBoost': AdaBoostRegressor(random_state=10),
    'RandomForest': RandomForestRegressor(random_state=10)
}

# Dictionary of results
results = {}

# fit, predict, and evaluate
for name, model in models.items():    

    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    mse = mean_squared_error(y_test, y_pred)
    rmse = mse ** 0.5
    r2 = r2_score(y_test, y_pred)
    
    results[name] = (mse, rmse, r2)

for model, metrics in results.items():
    print(f"{model} - MSE: {metrics[0]}, RMSE: {metrics[1]}, R^2: {metrics[2]}")
# Out:
# Bagging - MSE: 393.27817283923, RMSE: 19.831242342304982, R^2: 0.6600063864832426
# AdaBoost - MSE: 683.2700522217565, RMSE: 26.139434810679372, R^2: 0.409304990445975
# RandomForest - MSE: 393.2701800087117, RMSE: 19.831040820106033, R^2: 0.660013296379387

# %% [markdown]
# ### Scaling

# %%
normalizer = MinMaxScaler()

# training dataset 
normalizer.fit(X_train)
X_train_norm = normalizer.transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %%
model = KNeighborsRegressor()
model.fit(X_train_norm, y_train)
    
# Prediction and evaluation
y_pred = model.predict(X_test_norm)
    
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)
    
print(f"{model} - MSE: {metrics[0]}, RMSE: {metrics[1]}, R^2: {metrics[2]}")
# Out:
# KNeighborsRegressor() - MSE: 393.2701800087117, RMSE: 19.831040820106033, R^2: 0.660013296379387
